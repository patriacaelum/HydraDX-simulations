# %% [markdown]
# # Static Fees with Constant Price Oracles

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 9, 30)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0, 0, 0, 0, 0, 0, 0]
# SubsetIDs: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Ns       : [0, 1, 2, 3, 4, 5, 6, 7, 8]
# ExpIDs   : [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Execution Mode: parallelized
# {'q_sold': 2100, 'ri_sold': 1050, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.5, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 1, 'oracle_price_j': 2, 'oracle_price_hydra': 2, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1050
#  R removed from pool of  j  =  1047.7996207962278
# {'q_sold': 1974, 'ri_sold': 987, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.870000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  987
#  R removed from pool of  i  =  989.192985116737
# {'q_sold': 2130, 'ri_sold': 1065, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.65, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1065
#  R removed from pool of  j  =  1062.4782059729332
# {'q_sold': 2306, 'ri_sold': 1153, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.53, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1153
#  R removed from pool of  j  =  1145.190385563299
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.77, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  977
#  R removed from pool of  i  =  983.9943838428007
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.77, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  977
#  R removed from pool of  i  =  980.1465137250489
# {'q_sold': 2316, 'ri_sold': 1158, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.58, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1158
#  R removed from pool of  j  =  1153.8731518315617
# {'q_sold': 2154, 'ri_sold': 1077, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.77, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1077
#  R removed from pool of  j  =  1068.389121614513
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.540000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  954
#  R removed from pool of  i  =  961.90965040843
# {'q_sold': 2110, 'ri_sold': 1044.45, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 10.55, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A'}
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.540000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  954
#  R removed from pool of  j  =  946.2130521885119
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.540000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  954
#  R removed from pool of  j  =  942.712436192669
# {'q_sold': 2050, 'ri_sold': 1025, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.25, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1025
#  R removed from pool of  i  =  1037.1053766079713
# {'q_sold': 1618, 'ri_sold': 809, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.09, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  809
#  R removed from pool of  j  =  799.9109286576277
# {'q_sold': 1656, 'ri_sold': 828, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.28, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  828
#  R removed from pool of  j  =  816.1018249242334
# {'q_sold': 1888, 'ri_sold': 944, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.44, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  944
#  R removed from pool of  j  =  927.2475883791922
# {'q_sold': 1798, 'ri_sold': 899, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.99, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  899
#  R removed from pool of  j  =  879.9054155120393
# {'q_sold': 2064, 'ri_sold': 1032, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.32, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1032
#  R removed from pool of  i  =  1054.0790390621405
# {'q_sold': 1820, 'ri_sold': 910, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.1, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  910
#  R removed from pool of  j  =  891.1866774695227
# {'q_sold': 1718, 'ri_sold': 859, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.59, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  859
#  R removed from pool of  i  =  877.1895012583118
# {'q_sold': 2294, 'ri_sold': 1147, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.47, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1147
#  R removed from pool of  j  =  1122.6309662254062
# {'q_sold': 1956, 'ri_sold': 978, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.78, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  978
#  R removed from pool of  j  =  953.3043534909375
# {'q_sold': 2014, 'ri_sold': 1007, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.07, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1007
#  R removed from pool of  j  =  977.8271532264771
# {'q_sold': 1716, 'ri_sold': 858, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.58, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  858
#  R removed from pool of  j  =  830.1621385130566
# {'q_sold': 1892, 'ri_sold': 946, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.46, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  946
#  R removed from pool of  i  =  977.4976962532382
# {'q_sold': 2024, 'ri_sold': 1012, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.120000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1012
#  R removed from pool of  i  =  1041.6437116749585
# {'q_sold': 1770, 'ri_sold': 885, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.85, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  885
#  R removed from pool of  i  =  907.5102010446135
# {'q_sold': 2076, 'ri_sold': 1038, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.38, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1038
#  R removed from pool of  i  =  1060.3668903042562
# {'q_sold': 1880, 'ri_sold': 940, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.4, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  940
#  R removed from pool of  j  =  920.3858531435253
# {'q_sold': 1942, 'ri_sold': 971, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.71, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  971
#  R removed from pool of  i  =  991.5938382027671
# {'q_sold': 1880, 'ri_sold': 940, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.4, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  940
#  R removed from pool of  i  =  956.327217772603
# {'q_sold': 2372, 'ri_sold': 1186, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.86, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1186
#  R removed from pool of  i  =  1201.5648987360764
# {'q_sold': 1998, 'ri_sold': 999, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.99, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  999
#  R removed from pool of  i  =  1007.7784453528002
# {'q_sold': 1790, 'ri_sold': 895, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.950000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  895
#  R removed from pool of  j  =  887.398282136186
# {'q_sold': 2166, 'ri_sold': 1083, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.83, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1083
#  R removed from pool of  j  =  1069.6845863411436
# {'q_sold': 1756, 'ri_sold': 878, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.78, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  878
#  R removed from pool of  j  =  863.9143951728474
# {'q_sold': 2042, 'ri_sold': 1021, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.21, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1021
#  R removed from pool of  j  =  1000.935992488754
# {'q_sold': 1610, 'ri_sold': 805, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.05, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  805
#  R removed from pool of  j  =  786.4020666213473
# {'q_sold': 1736, 'ri_sold': 868, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.68, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  868
#  R removed from pool of  i  =  888.3845940660685
# {'q_sold': 2040, 'ri_sold': 1020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1020
#  R removed from pool of  j  =  996.342548216111
# {'q_sold': 2148, 'ri_sold': 1074, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.74, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1074
#  R removed from pool of  j  =  1044.864071433898
# {'q_sold': 2036, 'ri_sold': 1018, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.18, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1018
#  R removed from pool of  j  =  986.4053276859922
# {'q_sold': 1978, 'ri_sold': 989, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.89, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  989
#  R removed from pool of  i  =  1020.6725324369036
# {'q_sold': 1940, 'ri_sold': 970, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.700000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  970
#  R removed from pool of  i  =  997.185726336902
# {'q_sold': 1706, 'ri_sold': 853, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.53, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  853
#  R removed from pool of  j  =  829.9753440787317
# {'q_sold': 1858, 'ri_sold': 929, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.290000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  929
#  R removed from pool of  j  =  900.8298470210284
# {'q_sold': 1908, 'ri_sold': 954, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.540000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  954
#  R removed from pool of  i  =  983.7292436941061
# {'q_sold': 2212, 'ri_sold': 1106, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.06, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1106
#  R removed from pool of  i  =  1135.8227944965474
# {'q_sold': 2070, 'ri_sold': 1035, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.35, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1035
#  R removed from pool of  j  =  1008.0200512880692
# {'q_sold': 1648, 'ri_sold': 824, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.24, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  824
#  R removed from pool of  i  =  846.3624123642221
# {'q_sold': 2066, 'ri_sold': 1033, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.33, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1033
#  R removed from pool of  i  =  1057.1468493428547
# {'q_sold': 1924, 'ri_sold': 962, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.620000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  962
#  R removed from pool of  i  =  980.6193590159528
# {'q_sold': 1866, 'ri_sold': 933, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.33, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  933
#  R removed from pool of  j  =  915.3690172767965
# {'q_sold': 2124, 'ri_sold': 1062, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.620000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1062
#  R removed from pool of  i  =  1082.1427696950268
# {'q_sold': 2208, 'ri_sold': 1104, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.040000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1104
#  R removed from pool of  j  =  1083.4046320555499
# {'q_sold': 2188, 'ri_sold': 1094, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.94, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1094
#  R removed from pool of  j  =  1069.04171650426
# {'q_sold': 1834, 'ri_sold': 917, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.17, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  917
#  R removed from pool of  j  =  892.6117050021421
# {'q_sold': 1940, 'ri_sold': 970, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.700000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  970
#  R removed from pool of  i  =  996.3502813111991
# {'q_sold': 2068, 'ri_sold': 1034, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.34, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1034
#  R removed from pool of  i  =  1057.8899237522855
# {'q_sold': 2196, 'ri_sold': 1098, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.98, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1098
#  R removed from pool of  j  =  1073.1212886677822
# {'q_sold': 1906, 'ri_sold': 953, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.53, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  953
#  R removed from pool of  j  =  927.7302285314072
# {'q_sold': 1964, 'ri_sold': 982, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.82, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  982
#  R removed from pool of  j  =  952.4079724657349
# {'q_sold': 1780, 'ri_sold': 890, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.9, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  890
#  R removed from pool of  j  =  860.0816732982639
# {'q_sold': 1762, 'ri_sold': 881, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.81, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  881
#  R removed from pool of  j  =  848.4976702652639
# {'q_sold': 2164, 'ri_sold': 1082, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.82, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1082
#  R removed from pool of  j  =  1038.1742359598866
# {'q_sold': 2272, 'ri_sold': 1136, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.36, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1136
#  R removed from pool of  j  =  1085.3783103500027
# {'q_sold': 1986, 'ri_sold': 993, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.93, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  993
#  R removed from pool of  j  =  944.9073135522194
# {'q_sold': 2202, 'ri_sold': 1101, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.01, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1101
#  R removed from pool of  j  =  1043.5111786964117
# {'q_sold': 2074, 'ri_sold': 1037, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.370000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1037
#  R removed from pool of  j  =  978.8708993234904
# {'q_sold': 1872, 'ri_sold': 936, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.36, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  936
#  R removed from pool of  j  =  880.2349217316369
# {'q_sold': 2074, 'ri_sold': 1037, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.370000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1037
#  R removed from pool of  j  =  971.5849339906126
# {'q_sold': 2308, 'ri_sold': 1154, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.540000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1154
#  R removed from pool of  i  =  1231.2441676619928
# {'q_sold': 1994, 'ri_sold': 997, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.97, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  997
#  R removed from pool of  j  =  934.8649677224457
# {'q_sold': 2314, 'ri_sold': 1157, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.57, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1157
#  R removed from pool of  j  =  1080.4892574219266
# {'q_sold': 1478, 'ri_sold': 739, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 7.390000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  739
#  R removed from pool of  i  =  791.8752106947359
# {'q_sold': 2166, 'ri_sold': 1083, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.83, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1083
#  R removed from pool of  j  =  1010.131530564162
# {'q_sold': 2018, 'ri_sold': 1009, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.09, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1009
#  R removed from pool of  j  =  937.4090818834957
# {'q_sold': 1942, 'ri_sold': 971, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.71, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  971
#  R removed from pool of  i  =  1045.0852513739374
# {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.1, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1010
#  R removed from pool of  i  =  1082.7122174312826
# {'q_sold': 1604, 'ri_sold': 802, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.02, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  802
#  R removed from pool of  j  =  748.5355265327962
# {'q_sold': 1958, 'ri_sold': 979, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.790000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  979
#  R removed from pool of  i  =  1048.437562103616
# {'q_sold': 2072, 'ri_sold': 1036, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.36, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1036
#  R removed from pool of  j  =  967.4088499392383
# {'q_sold': 2296, 'ri_sold': 1148, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.48, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1148
#  R removed from pool of  j  =  1067.590367815108
# {'q_sold': 1898, 'ri_sold': 949, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.49, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  949
#  R removed from pool of  i  =  1020.7223521354608
# {'q_sold': 1840, 'ri_sold': 920, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  920
#  R removed from pool of  i  =  985.7964197206311
# {'q_sold': 1900, 'ri_sold': 950, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.5, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  950
#  R removed from pool of  i  =  1014.1058356645517
# {'q_sold': 2184, 'ri_sold': 1092, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.92, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1092
#  R removed from pool of  i  =  1160.9015502810944
# {'q_sold': 2066, 'ri_sold': 1033, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.33, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1033
#  R removed from pool of  j  =  971.924762106617
# {'q_sold': 1896, 'ri_sold': 948, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.48, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  948
#  R removed from pool of  i  =  1007.6202934477478
# 49920.73802536745
# {'q_sold': 2104, 'ri_sold': 1041.48, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 10.52, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A', 'UNI_burn': 49920.73802536745}
# Ri_plus =  964974.4962061525
# {'q_sold': 2020, 'ri_sold': 1010, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.1, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1010
#  R removed from pool of  j  =  950.1897373996908
# {'q_sold': 2194, 'ri_sold': 1097, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.97, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1097
#  R removed from pool of  i  =  1165.6986740225693
# {'q_sold': 1860, 'ri_sold': 930, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.3, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  930
#  R removed from pool of  j  =  875.5919483470498
# {'q_sold': 1936, 'ri_sold': 968, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.68, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  968
#  R removed from pool of  j  =  908.0202286037384
# {'q_sold': 1922, 'ri_sold': 961, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.61, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  961
#  R removed from pool of  j  =  898.0939544859575
# {'q_sold': 1708, 'ri_sold': 854, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.540000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  854
#  R removed from pool of  j  =  795.3037045298843
# {'q_sold': 2060, 'ri_sold': 1030, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.3, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1030
#  R removed from pool of  i  =  1105.4802911954466
# {'q_sold': 2054, 'ri_sold': 1027, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.27, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1027
#  R removed from pool of  j  =  957.0230958537431
# {'q_sold': 2002, 'ri_sold': 1001, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.01, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1001
#  R removed from pool of  i  =  1074.0946686696261
# {'q_sold': 1954, 'ri_sold': 977, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.77, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  977
#  R removed from pool of  j  =  910.683451352641
# {'q_sold': 1718, 'ri_sold': 859, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.59, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 2, 'oracle_price_j': 2, 'oracle_price_hydra': 2, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  859
#  R removed from pool of  i  =  857.5267690108158
# {'q_sold': 1916, 'ri_sold': 958, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.58, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  958
#  R removed from pool of  i  =  952.8941613282077
# {'q_sold': 1932, 'ri_sold': 966, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.66, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  966
#  R removed from pool of  j  =  971.1505637250375
# {'q_sold': 1840, 'ri_sold': 920, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  920
#  R removed from pool of  j  =  921.4170832709642
# {'q_sold': 1968, 'ri_sold': 984, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.84, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  984
#  R removed from pool of  j  =  981.7707553834189
# {'q_sold': 2082, 'ri_sold': 1041, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.41, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1041
#  R removed from pool of  j  =  1034.4527219736483
# {'q_sold': 2378, 'ri_sold': 1189, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.89, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1189
#  R removed from pool of  i  =  1196.1549331415445
# {'q_sold': 2036, 'ri_sold': 1018, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.18, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1018
#  R removed from pool of  i  =  1019.6064721116563
# {'q_sold': 2052, 'ri_sold': 1026, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.26, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1026
#  R removed from pool of  i  =  1023.4277561693452
# {'q_sold': 1986, 'ri_sold': 983.0699999999999, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 9.93, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A'}
# ...
# {'q_sold': 2360, 'ri_sold': 1180, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 59.0, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1180
#  R removed from pool of  i  =  1201.0300016656984
# {'q_sold': 1878, 'ri_sold': 939, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  939
#  R removed from pool of  i  =  951.7578401046339
# {'q_sold': 1924, 'ri_sold': 962, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 48.1, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  962
#  R removed from pool of  i  =  971.4371170171071
# {'q_sold': 2058, 'ri_sold': 1029, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 51.45, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1029
#  R removed from pool of  j  =  1018.8898407657398
# {'q_sold': 2068, 'ri_sold': 1034, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 51.7, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1034
#  R removed from pool of  j  =  1019.7495599323884
# {'q_sold': 2132, 'ri_sold': 1066, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 53.300000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1066
#  R removed from pool of  i  =  1080.7985893373843
# {'q_sold': 2404, 'ri_sold': 1202, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 60.1, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1202
#  R removed from pool of  j  =  1185.2636367458617
# {'q_sold': 1966, 'ri_sold': 983, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 49.150000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  983
#  R removed from pool of  j  =  965.219374188222
# {'q_sold': 1842, 'ri_sold': 921, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.050000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  921
#  R removed from pool of  i  =  938.0476951750461
# {'q_sold': 1726, 'ri_sold': 863, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 43.150000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  863
#  R removed from pool of  j  =  847.4391136979684
# {'q_sold': 1854, 'ri_sold': 927, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.35, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  927
#  R removed from pool of  i  =  943.8739720089361
# {'q_sold': 1994, 'ri_sold': 997, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 49.85, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  997
#  R removed from pool of  i  =  1011.3113872003742
# {'q_sold': 2360, 'ri_sold': 1180, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 59.0, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1180
#  R removed from pool of  i  =  1191.8313566476572
# {'q_sold': 1898, 'ri_sold': 949, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 47.45, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  949
#  R removed from pool of  j  =  940.0221715136431
# {'q_sold': 2046, 'ri_sold': 1023, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 51.150000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1023
#  R removed from pool of  i  =  1032.602393642068
# {'q_sold': 1998, 'ri_sold': 999, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 49.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  999
#  R removed from pool of  j  =  989.7746484982781
# {'q_sold': 2238, 'ri_sold': 1119, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 55.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1119
#  R removed from pool of  i  =  1129.1438912071753
# {'q_sold': 2506, 'ri_sold': 1253, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 62.650000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1253
#  R removed from pool of  i  =  1258.4976920324843
# {'q_sold': 1894, 'ri_sold': 947, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 47.35, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  947
#  R removed from pool of  j  =  943.4348755105166
# {'q_sold': 1904, 'ri_sold': 952, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 47.6, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  952
#  R removed from pool of  i  =  955.5814960948192
# {'q_sold': 2210, 'ri_sold': 1105, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 55.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1105
#  R removed from pool of  j  =  1100.5383374317316
# {'q_sold': 2138, 'ri_sold': 1069, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 53.45, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1069
#  R removed from pool of  j  =  1060.188023747527
# {'q_sold': 2370, 'ri_sold': 1185, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 59.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1185
#  R removed from pool of  i  =  1194.5573842849117
# {'q_sold': 2118, 'ri_sold': 1059, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 52.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1059
#  R removed from pool of  j  =  1050.8038479624083
# {'q_sold': 1930, 'ri_sold': 965, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 48.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  965
#  R removed from pool of  j  =  953.7731722715544
# {'q_sold': 2120, 'ri_sold': 1060, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 53.0, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1060
#  R removed from pool of  i  =  1072.2537445044145
# 49847.219998621214
# {'q_sold': 2222, 'ri_sold': 1055.45, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 55.550000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A', 'UNI_burn': 49847.219998621214}
# Ri_plus =  954558.0018321575
# {'q_sold': 2166, 'ri_sold': 1083, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 54.150000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1083
#  R removed from pool of  i  =  1090.8678109969478
# {'q_sold': 2102, 'ri_sold': 1051, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 52.550000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1051
#  R removed from pool of  i  =  1054.1152269805316
# {'q_sold': 2214, 'ri_sold': 1107, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 55.35, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1107
#  R removed from pool of  j  =  1103.6120513074566
# {'q_sold': 2234, 'ri_sold': 1117, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 55.85, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1117
#  R removed from pool of  i  =  1120.3990359945456
# {'q_sold': 2278, 'ri_sold': 1139, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 56.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1139
#  R removed from pool of  j  =  1135.5024020343553
# {'q_sold': 2130, 'ri_sold': 1065, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 53.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1065
#  R removed from pool of  i  =  1068.431146710529
# {'q_sold': 1968, 'ri_sold': 984, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 49.2, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  984
#  R removed from pool of  j  =  981.0052038769936
# {'q_sold': 2030, 'ri_sold': 1015, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 50.75, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1015
#  R removed from pool of  i  =  1018.0293231512187
# {'q_sold': 2242, 'ri_sold': 1121, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 56.050000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1121
#  R removed from pool of  j  =  1117.4347237091279
# {'q_sold': 1838, 'ri_sold': 919, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 45.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  919
#  R removed from pool of  j  =  912.3565842054086
# Total execution time: 1.94s

# %%
impermanent_loss_plot(rdf)

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 9, 30)
# Execution Method: local_simulations
# SimIDs   : [0, 0, 0, 0, 0, 0, 0, 0, 0]
# SubsetIDs: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# Ns       : [0, 1, 2, 3, 4, 5, 6, 7, 8]
# ExpIDs   : [0, 0, 0, 0, 0, 0, 0, 0, 0]
# Execution Mode: parallelized
# {'q_sold': 2074, 'ri_sold': 1037, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.370000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 1, 'oracle_price_j': 2, 'oracle_price_hydra': 2, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1037
#  R removed from pool of  j  =  1034.8537133983336
# {'q_sold': 1922, 'ri_sold': 961, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.61, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  961
#  R removed from pool of  j  =  955.1940557162743
# {'q_sold': 2006, 'ri_sold': 1003, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.03, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1003
#  R removed from pool of  i  =  1008.9998501020018
# {'q_sold': 2256, 'ri_sold': 1128, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.28, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1128
#  R removed from pool of  j  =  1121.02679245756
# {'q_sold': 2040, 'ri_sold': 1020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1020
#  R removed from pool of  j  =  1009.3667605363298
# {'q_sold': 2010, 'ri_sold': 1005, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.05, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1005
#  R removed from pool of  j  =  990.5284053357318
# {'q_sold': 1730, 'ri_sold': 865, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.65, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  865
#  R removed from pool of  j  =  849.3874462302774
# {'q_sold': 2150, 'ri_sold': 1075, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.75, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1075
#  R removed from pool of  i  =  1094.2616796862567
# {'q_sold': 2130, 'ri_sold': 1065, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.65, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1065
#  R removed from pool of  j  =  1046.314024080988
# {'q_sold': 2434, 'ri_sold': 1204.83, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 12.17, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A'}
# {'q_sold': 1940, 'ri_sold': 970, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.700000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  970
#  R removed from pool of  i  =  987.5209780442528
# {'q_sold': 2044, 'ri_sold': 1022, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.22, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1022
#  R removed from pool of  i  =  1036.3894740275573
# {'q_sold': 2050, 'ri_sold': 1025, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.25, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1025
#  R removed from pool of  j  =  1010.7909575338708
# {'q_sold': 2316, 'ri_sold': 1158, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.58, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1158
#  R removed from pool of  j  =  1137.1296965366928
# {'q_sold': 1982, 'ri_sold': 991, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.91, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  991
#  R removed from pool of  i  =  1009.4786220493261
# {'q_sold': 2056, 'ri_sold': 1028, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.28, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1028
#  R removed from pool of  j  =  1009.1462214853382
# {'q_sold': 2122, 'ri_sold': 1061, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.61, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1061
#  R removed from pool of  j  =  1037.3449855085928
# {'q_sold': 2038, 'ri_sold': 1019, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.19, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1019
#  R removed from pool of  i  =  1042.274400972994
# {'q_sold': 1912, 'ri_sold': 956, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.56, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  956
#  R removed from pool of  i  =  974.0331742987037
# {'q_sold': 2040, 'ri_sold': 1020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1020
#  R removed from pool of  j  =  1001.0268823192455
# {'q_sold': 2216, 'ri_sold': 1108, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.08, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1108
#  R removed from pool of  j  =  1082.928444952122
# {'q_sold': 1796, 'ri_sold': 898, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.98, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  898
#  R removed from pool of  i  =  919.1254706883337
# {'q_sold': 2028, 'ri_sold': 1014, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.14, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1014
#  R removed from pool of  j  =  990.5127116902731
# {'q_sold': 1860, 'ri_sold': 930, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.3, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  930
#  R removed from pool of  i  =  952.1661021765321
# {'q_sold': 2240, 'ri_sold': 1120, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1120
#  R removed from pool of  i  =  1142.0653007291257
# {'q_sold': 1696, 'ri_sold': 848, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.48, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  848
#  R removed from pool of  i  =  861.3608732928988
# {'q_sold': 1890, 'ri_sold': 945, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.450000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  945
#  R removed from pool of  j  =  930.1911837653024
# {'q_sold': 2076, 'ri_sold': 1038, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.38, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1038
#  R removed from pool of  j  =  1017.8206807196839
# {'q_sold': 2314, 'ri_sold': 1157, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.57, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1157
#  R removed from pool of  i  =  1179.61531563662
# {'q_sold': 1988, 'ri_sold': 994, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.94, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  994
#  R removed from pool of  i  =  1009.1451775289606
# {'q_sold': 1890, 'ri_sold': 945, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.450000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  945
#  R removed from pool of  i  =  955.7494283707347
# {'q_sold': 2378, 'ri_sold': 1189, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.89, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1189
#  R removed from pool of  i  =  1197.5027619944885
# {'q_sold': 1712, 'ri_sold': 856, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.56, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  856
#  R removed from pool of  i  =  858.6768182150554
# {'q_sold': 1562, 'ri_sold': 781, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 7.8100000000000005, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  781
#  R removed from pool of  j  =  778.6831371412845
# {'q_sold': 2090, 'ri_sold': 1045, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.450000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1045
#  R removed from pool of  i  =  1047.564176617423
# {'q_sold': 1900, 'ri_sold': 950, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.5, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  950
#  R removed from pool of  i  =  948.6278723550495
# {'q_sold': 1796, 'ri_sold': 898, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.98, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  898
#  R removed from pool of  i  =  893.4786661519902
# {'q_sold': 2142, 'ri_sold': 1071, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.71, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1071
#  R removed from pool of  j  =  1076.0460979694035
# {'q_sold': 2050, 'ri_sold': 1025, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.25, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1025
#  R removed from pool of  i  =  1020.294620289118
# {'q_sold': 1888, 'ri_sold': 944, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.44, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  944
#  R removed from pool of  i  =  936.0726756027434
# {'q_sold': 1744, 'ri_sold': 872, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.72, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  872
#  R removed from pool of  j  =  879.4950945076998
# {'q_sold': 2176, 'ri_sold': 1088, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.88, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1088
#  R removed from pool of  j  =  1093.1470578175504
# {'q_sold': 2132, 'ri_sold': 1066, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.66, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1066
#  R removed from pool of  i  =  1061.0368073800346
# {'q_sold': 1982, 'ri_sold': 991, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.91, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  991
#  R removed from pool of  i  =  982.4455791572109
# {'q_sold': 2370, 'ri_sold': 1185, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.85, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1185
#  R removed from pool of  i  =  1169.817871373496
# {'q_sold': 1786, 'ri_sold': 893, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.93, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  893
#  R removed from pool of  i  =  878.0156422505388
# {'q_sold': 1696, 'ri_sold': 848, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.48, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  848
#  R removed from pool of  j  =  862.5230366436299
# {'q_sold': 1862, 'ri_sold': 931, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.31, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  931
#  R removed from pool of  j  =  943.6363042948069
# {'q_sold': 1992, 'ri_sold': 996, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.96, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  996
#  R removed from pool of  j  =  1005.7057750398526
# {'q_sold': 2050, 'ri_sold': 1025, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.25, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1025
#  R removed from pool of  j  =  1030.8969534718199
# {'q_sold': 1952, 'ri_sold': 976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.76, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  976
#  R removed from pool of  j  =  977.7803431375651
# {'q_sold': 2072, 'ri_sold': 1036, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.36, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1036
#  R removed from pool of  j  =  1033.821184575092
# {'q_sold': 1750, 'ri_sold': 875, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.75, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  875
#  R removed from pool of  j  =  869.9142883891473
# {'q_sold': 2290, 'ri_sold': 1145, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.450000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1145
#  R removed from pool of  j  =  1133.882405374432
# {'q_sold': 1984, 'ri_sold': 992, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.92, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  992
#  R removed from pool of  j  =  978.3016453804448
# {'q_sold': 2224, 'ri_sold': 1112, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.120000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1112
#  R removed from pool of  i  =  1127.2744037297089
# {'q_sold': 2070, 'ri_sold': 1035, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.35, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1035
#  R removed from pool of  i  =  1044.802395340521
# {'q_sold': 2092, 'ri_sold': 1046, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.46, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1046
#  R removed from pool of  i  =  1051.609463549219
# {'q_sold': 2114, 'ri_sold': 1057, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.57, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1057
#  R removed from pool of  j  =  1051.350758497254
# {'q_sold': 2090, 'ri_sold': 1045, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.450000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1045
#  R removed from pool of  j  =  1035.1736669486854
# {'q_sold': 2130, 'ri_sold': 1065, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.65, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1065
#  R removed from pool of  i  =  1075.0466232139152
# {'q_sold': 2266, 'ri_sold': 1133, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.33, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1133
#  R removed from pool of  j  =  1122.285529653891
# {'q_sold': 2040, 'ri_sold': 1020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.200000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1020
#  R removed from pool of  j  =  1006.1402837913483
# {'q_sold': 2142, 'ri_sold': 1071, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.71, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1071
#  R removed from pool of  i  =  1085.614888977958
# {'q_sold': 1984, 'ri_sold': 992, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.92, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  992
#  R removed from pool of  j  =  978.8228892864427
# {'q_sold': 2290, 'ri_sold': 1145, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.450000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1145
#  R removed from pool of  j  =  1125.1230698066065
# {'q_sold': 1866, 'ri_sold': 933, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.33, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  933
#  R removed from pool of  j  =  913.1269842910115
# {'q_sold': 2362, 'ri_sold': 1181, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.81, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1181
#  R removed from pool of  i  =  1206.0659118832555
# {'q_sold': 1992, 'ri_sold': 996, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.96, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  996
#  R removed from pool of  i  =  1012.7842530251946
# {'q_sold': 1714, 'ri_sold': 857, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.57, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  857
#  R removed from pool of  i  =  868.2712263665162
# {'q_sold': 2026, 'ri_sold': 1013, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.13, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1013
#  R removed from pool of  j  =  999.5696492515272
# {'q_sold': 1864, 'ri_sold': 932, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.32, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  932
#  R removed from pool of  j  =  916.1842078177724
# {'q_sold': 2170, 'ri_sold': 1085, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.85, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1085
#  R removed from pool of  i  =  1103.3635512390174
# {'q_sold': 1870, 'ri_sold': 935, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.35, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  935
#  R removed from pool of  j  =  919.7380437038373
# {'q_sold': 1912, 'ri_sold': 956, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.56, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  956
#  R removed from pool of  j  =  936.9613042366691
# {'q_sold': 1624, 'ri_sold': 812, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.120000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  812
#  R removed from pool of  i  =  828.703564462252
# {'q_sold': 1910, 'ri_sold': 955, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.55, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  955
#  R removed from pool of  i  =  971.2575201182626
# {'q_sold': 1516, 'ri_sold': 758, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 7.58, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  758
#  R removed from pool of  i  =  768.3101130281575
# {'q_sold': 1684, 'ri_sold': 842, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 8.42, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  842
#  R removed from pool of  j  =  830.5824240498478
# {'q_sold': 2154, 'ri_sold': 1077, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.77, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1077
#  R removed from pool of  i  =  1091.2767711651977
# {'q_sold': 2158, 'ri_sold': 1079, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.790000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1079
#  R removed from pool of  i  =  1088.6855085969437
# {'q_sold': 2086, 'ri_sold': 1043, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.43, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1043
#  R removed from pool of  i  =  1047.9965219171718
# {'q_sold': 1808, 'ri_sold': 904, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.040000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  904
#  R removed from pool of  i  =  904.8792018687818
# {'q_sold': 1992, 'ri_sold': 996, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.96, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  996
#  R removed from pool of  i  =  993.2790574035607
# {'q_sold': 2000, 'ri_sold': 1000, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.0, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1000
#  R removed from pool of  j  =  1002.7261908674845
# {'q_sold': 1770, 'ri_sold': 885, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 8.85, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  885
#  R removed from pool of  i  =  882.7963131130673
# {'q_sold': 2302, 'ri_sold': 1151, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.51, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1151
#  R removed from pool of  j  =  1153.2690707459114
# {'q_sold': 2176, 'ri_sold': 1088, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.88, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1088
#  R removed from pool of  i  =  1085.997443362372
# {'q_sold': 1956, 'ri_sold': 978, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.78, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  978
#  R removed from pool of  i  =  972.2775816010544
# 49752.34583415803
# {'q_sold': 2006, 'ri_sold': 992.97, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 10.03, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A', 'UNI_burn': 49752.34583415803}
# Ri_plus =  951100.9346105893
# {'q_sold': 2042, 'ri_sold': 1021, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.21, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1021
#  R removed from pool of  i  =  1011.0391994059319
# {'q_sold': 1592, 'ri_sold': 796, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 7.96, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  796
#  R removed from pool of  i  =  785.3917149376357
# {'q_sold': 1952, 'ri_sold': 976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.76, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  976
#  R removed from pool of  j  =  988.8037087759003
# {'q_sold': 1864, 'ri_sold': 932, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.32, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  932
#  R removed from pool of  j  =  940.6107099344954
# {'q_sold': 1800, 'ri_sold': 900, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.0, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  900
#  R removed from pool of  i  =  891.8330801345874
# {'q_sold': 1944, 'ri_sold': 972, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.72, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  972
#  R removed from pool of  i  =  959.6007136631524
# {'q_sold': 2360, 'ri_sold': 1180, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.8, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1180
#  R removed from pool of  i  =  1159.982787197805
# {'q_sold': 2130, 'ri_sold': 1065, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.65, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1065
#  R removed from pool of  j  =  1083.5854797941865
# {'q_sold': 1886, 'ri_sold': 943, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 9.43, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  943
#  R removed from pool of  i  =  927.0839225212112
# {'q_sold': 2116, 'ri_sold': 1058, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.58, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1058
#  R removed from pool of  j  =  1075.879835914704
# {'q_sold': 2280, 'ri_sold': 1140, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.4, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 2, 'oracle_price_j': 2, 'oracle_price_hydra': 2, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1140
#  R removed from pool of  i  =  1137.406712695025
# {'q_sold': 2186, 'ri_sold': 1093, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.93, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1093
#  R removed from pool of  i  =  1085.6650488179876
# {'q_sold': 2012, 'ri_sold': 1006, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.06, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1006
#  R removed from pool of  j  =  1012.9584823288023
# {'q_sold': 1872, 'ri_sold': 936, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 9.36, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  936
#  R removed from pool of  j  =  938.8116646177368
# {'q_sold': 2140, 'ri_sold': 1070, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.700000000000001, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1070
#  R removed from pool of  i  =  1066.5162891329965
# {'q_sold': 2080, 'ri_sold': 1040, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.4, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1040
#  R removed from pool of  j  =  1043.4524651138345
# {'q_sold': 2180, 'ri_sold': 1090, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.9, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1090
#  R removed from pool of  i  =  1086.2926673952024
# {'q_sold': 2128, 'ri_sold': 1064, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 10.64, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1064
#  R removed from pool of  i  =  1055.8353586094454
# {'q_sold': 2210, 'ri_sold': 1105, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 11.05, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1105
#  R removed from pool of  i  =  1091.7977285699453
# {'q_sold': 1894, 'ri_sold': 937.53, 'ri_deposit': 50000, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'AddLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 9.47, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A'}
# {'q_sold': 2264, 'ri_sold': 1132, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 11.32, 'fee_percent': 1.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1132
#  R removed from pool of  j  =  1145.657886177185
# ...
#  R to R swap called
#  R added to pool of  i  =  840
#  R removed from pool of  j  =  841.8626451019663
# {'q_sold': 1952, 'ri_sold': 976, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 48.800000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  976
#  R removed from pool of  i  =  973.5860927167814
# {'q_sold': 1832, 'ri_sold': 916, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 45.800000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  916
#  R removed from pool of  i  =  910.3726103879744
# {'q_sold': 2436, 'ri_sold': 1218, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 60.900000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1218
#  R removed from pool of  j  =  1224.7917294071522
# {'q_sold': 1966, 'ri_sold': 983, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 49.150000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  983
#  R removed from pool of  j  =  984.2350420370931
# {'q_sold': 2026, 'ri_sold': 1013, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 50.650000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1013
#  R removed from pool of  j  =  1010.3292575591477
# {'q_sold': 2112, 'ri_sold': 1056, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 52.800000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1056
#  R removed from pool of  j  =  1048.9799528339645
# {'q_sold': 2010, 'ri_sold': 1005, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 50.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1005
#  R removed from pool of  j  =  994.3271662906045
# {'q_sold': 2340, 'ri_sold': 1170, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 58.5, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1170
#  R removed from pool of  j  =  1152.701335453894
# {'q_sold': 1876, 'ri_sold': 938, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.900000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  938
#  R removed from pool of  i  =  952.4784166708123
# {'q_sold': 2040, 'ri_sold': 1020, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 51.0, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1020
#  R removed from pool of  i  =  1031.7659180865157
# {'q_sold': 1852, 'ri_sold': 926, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.300000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  926
#  R removed from pool of  i  =  933.1124287103303
# {'q_sold': 1736, 'ri_sold': 868, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 43.400000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  868
#  R removed from pool of  i  =  871.5996070704423
# {'q_sold': 1878, 'ri_sold': 939, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.95, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  939
#  R removed from pool of  i  =  939.5695886027534
# {'q_sold': 1994, 'ri_sold': 997, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 49.85, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  997
#  R removed from pool of  j  =  996.2840221973602
# {'q_sold': 1916, 'ri_sold': 958, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 47.900000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  958
#  R removed from pool of  j  =  953.6697150722612
# {'q_sold': 1862, 'ri_sold': 931, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.550000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  931
#  R removed from pool of  i  =  935.2687998290639
# {'q_sold': 1720, 'ri_sold': 860, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 43.0, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  860
#  R removed from pool of  j  =  856.2001659118105
# {'q_sold': 1984, 'ri_sold': 992, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 49.6, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  992
#  R removed from pool of  i  =  996.1380427584518
# {'q_sold': 1700, 'ri_sold': 850, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 42.5, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  850
#  R removed from pool of  i  =  850.477781516267
# {'q_sold': 2154, 'ri_sold': 1077, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 53.85, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1077
#  R removed from pool of  i  =  1073.5618776266929
# {'q_sold': 2018, 'ri_sold': 1009, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 50.45, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1009
#  R removed from pool of  i  =  1001.701582843205
# {'q_sold': 1710, 'ri_sold': 855, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 42.75, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  855
#  R removed from pool of  i  =  845.7457730225287
# {'q_sold': 1940, 'ri_sold': 970, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 48.5, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  970
#  R removed from pool of  j  =  980.3748972186586
# {'q_sold': 1850, 'ri_sold': 925, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  925
#  R removed from pool of  i  =  915.3094505912159
# {'q_sold': 2064, 'ri_sold': 1032, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 51.6, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1032
#  R removed from pool of  i  =  1017.3184352975804
# 50146.27970920863
# {'q_sold': 2270, 'ri_sold': 1078.25, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'RemoveLiquidity', 'agent_id': 2, 'asset_id': 'i', 'direction': '', 'direction_q': 'test_r_for_r', 'fee': 56.75, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'N/A', 'UNI_burn': 50146.27970920863}
# Ri_plus =  948790.3505501961
# {'q_sold': 1626, 'ri_sold': 813, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 40.650000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  813
#  R removed from pool of  j  =  825.0319687502924
# {'q_sold': 2024, 'ri_sold': 1012, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 50.6, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1012
#  R removed from pool of  i  =  996.8716321567772
# {'q_sold': 1968, 'ri_sold': 984, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 49.2, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  984
#  R removed from pool of  j  =  998.9589140880853
# {'q_sold': 2136, 'ri_sold': 1068, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 53.400000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1068
#  R removed from pool of  j  =  1079.7666736766696
# {'q_sold': 2044, 'ri_sold': 1022, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 51.1, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1022
#  R removed from pool of  j  =  1028.9307869734475
# {'q_sold': 1850, 'ri_sold': 925, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.25, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  925
#  R removed from pool of  i  =  918.9594530789182
# {'q_sold': 1938, 'ri_sold': 969, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 48.45, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  969
#  R removed from pool of  j  =  975.2716422531521
# {'q_sold': 1842, 'ri_sold': 921, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 46.050000000000004, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  921
#  R removed from pool of  i  =  915.1762776519172
# {'q_sold': 2216, 'ri_sold': 1108, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 55.400000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'j'}
#  R to R swap called
#  R added to pool of  i  =  1108
#  R removed from pool of  j  =  1114.6199477507034
# {'q_sold': 2006, 'ri_sold': 1003, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 50.150000000000006, 'fee_percent': 5.0, 'fees': [], 'oracle_price_i': 0, 'oracle_price_j': 0, 'oracle_price_hydra': 0, 'purchased_asset_id': 'i'}
#  R to R swap called
#  R added to pool of  j  =  1003
#  R removed from pool of  i  =  997.2646995001705
# Total execution time: 2.06s

# %%
impermanent_loss_plot(rdf)
