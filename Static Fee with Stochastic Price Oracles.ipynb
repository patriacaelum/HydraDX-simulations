# %% [markdown]
# # Case 1: No Fees with Stochastic Oracles $i < j$
#
# $\text{fee_percentage} = 0$
#
# $\text{oracle_price_i}_0 = 1.5$
#
# $\text{oracle_price_j}_0 = 2.5$
#
# $\text{oracle_price_hydra}_0 = 2$
#
# $\text{price delta} = 0.1$

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 1, 29)
# Execution Method: local_simulations
# SimIDs   : [0]
# SubsetIDs: [0]
# Ns       : [0]
# ExpIDs   : [0]
# Execution Mode: single_threaded
# {'q_sold': 2100, 'ri_sold': 1050, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 0.0, 'fee_percent': 0.0, 'oracle_price_i': 1.5, 'oracle_price_j': 2.5, 'oracle_price_hydra': 2, 'purchased_asset_id': 'j'}
# ...

# %%
impermanent_loss_plot(rdf)

# %%
AW_plot(rdf, 3, 300)

# %% [markdown]
# # Case 2: Static Fee $a = 1\%$ with Stochastic Price Oracles $i < j$
#
# $\text{fee_percentage} = 0.01$
#
# $\text{oracle_price_i}_0 = 1.5$
#
# $\text{oracle_price_j}_0 = 2.5$
#
# $\text{oracle_price_hydra}_0 = 2$
#
# $\text{price delta} = 0.1$

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 1, 29)
# Execution Method: local_simulations
# SimIDs   : [0]
# SubsetIDs: [0]
# Ns       : [0]
# ExpIDs   : [0]
# Execution Mode: single_threaded
# {'q_sold': 2100, 'ri_sold': 1050, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 10.5, 'fee_percent': 1.0, 'oracle_price_i': 1.5, 'oracle_price_j': 2.5, 'oracle_price_hydra': 2, 'purchased_asset_id': 'j'}
# ...

# %%
impermanent_loss_plot(rdf)

# %%
AW_plot(rdf, 3, 300)

# %% [markdown]
# # Case 3: Static Fee $a = 2\%$ with Constant Price Oracles $i < j$
#
# $\text{fee_percentage} = 0.02$
#
# $\text{oracle_price_i}_0 = 1.5$
#
# $\text{oracle_price_j}_0 = 2.5$
#
# $\text{oracle_price_hydra}_0 = 2$
#
# $\text{price delta} = 0.1$

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 1, 29)
# Execution Method: local_simulations
# SimIDs   : [0]
# SubsetIDs: [0]
# Ns       : [0]
# ExpIDs   : [0]
# Execution Mode: single_threaded
# {'q_sold': 2100, 'ri_sold': 1050, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'i', 'direction': 'ij', 'direction_q': 'test_r_for_r', 'fee': 21.0, 'fee_percent': 2.0, 'oracle_price_i': 1.5, 'oracle_price_j': 2.5, 'oracle_price_hydra': 2, 'purchased_asset_id': 'j'}
# ...

# %%
impermanent_loss_plot(rdf)

# %%
AW_plot(rdf, 3, 300)

# %% [markdown]
# # Case 4: Static Fee $a = 5\%$ with Constant Price Oracles $i < j$
#
# $\text{fee_percentage} = 0.05$
#
# $\text{oracle_price_i}_0 = 1.5$
#
# $\text{oracle_price_j}_0 = 2.5$
#
# $\text{oracle_price_hydra}_0 = 2$
#
# $\text{price delta} = 0.1$

# %%
# Dependences
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Experiments
from model import run
from model.parts.utils import *
from model.plot_utils import *

pd.options.display.float_format = '{:.2f}'.format

# %matplotlib inline

df = run.run()
rdf = run.postprocessing(df)
# Out:
# running file: run.py
# running file: asset_utils.py
# end of file: asset_utils.py
# running file: sim_setup.py
# end of file: sim_setup.py
# end of file: run.py
#
#                   ___________    ____
#   ________ __ ___/ / ____/   |  / __ \
#  / ___/ __` / __  / /   / /| | / / / /
# / /__/ /_/ / /_/ / /___/ ___ |/ /_/ /
# \___/\__,_/\__,_/\____/_/  |_/_____/
# by cadCAD
#
# Execution Mode: local_proc
# Configuration Count: 1
# Dimensions of the first simulation: (Timesteps, Params, Runs, Vars) = (100, 19, 1, 29)
# Execution Method: local_simulations
# SimIDs   : [0]
# SubsetIDs: [0]
# Ns       : [0]
# ExpIDs   : [0]
# Execution Mode: single_threaded
# {'q_sold': 2100, 'ri_sold': 1050, 'ri_deposit': 0, 'q_deposit': 0, 'Si_burn': 0, 'action_id': 'R_Swap', 'agent_id': 5, 'asset_id': 'j', 'direction': 'ji', 'direction_q': 'test_r_for_r', 'fee': 52.5, 'fee_percent': 5.0, 'oracle_price_i': 1.5, 'oracle_price_j': 2.5, 'oracle_price_hydra': 2, 'purchased_asset_id': 'i'}
# ...

# %%
impermanent_loss_plot(rdf)

# %%
AW_plot(rdf, 3, 300)
